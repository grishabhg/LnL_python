# %% [markdown]
# # Introduction to Machine Learning
#
# ## By Data Science Team at Myant

# %% [markdown]
# # What is Machine Learning?
#
# ##### Concept that deals with study and construction of systems that:
# * Extract meaning from data
# * Learn from data while improving their performance with experience.
#
#
# <img src="img/ecg.png" style="width: 400px;"/>

# %% [markdown]
# # Why use Machine Learning?
#
# ##### Mimic humans and replace monotonous tasks. Example: self-driven cars, SKIIN signal quality estimators
#
# ##### Systems that automatically adapt and customize to users. Example: recommender systems of Netflix, Spotify etc,
#
# ##### Natural language processing. Example: sentiment analysis algorithms of Twitter
#
# ##### Other examples: Prisma filters on Instagram, Deep dreams featured in Cold Ft. Future by Maroon 5

# %% [markdown]
# <img src="img/deepdreams.png" style="width: 800px;"/>

# %% [markdown]
# # How to make a machine learn?
#
# <img src="img/ml1.jpg" style="width: 500px;"/>

# %% [markdown]
# # Types of Machine Learning
# ##### Supervised: correct classes of training data are known.
# * Regression
# * Classification
#
# ##### Unsupervised: correct classes of training  data are unknown.
# * Clustering
# <img src="img/regclassclus.png" style="width: 500px;"/>

# %% [markdown]
# ##### Reinforcement learning: system learns its behaviour based on feedback from enviroment
#
# [Google's DeepMind](https://www.youtube.com/watch?v=gn4nRCC9TwQ "link title")

# %% [markdown]
# # Typical Machine Learning Pipeline
# <img src="img/mlpipeline.png" style="width:1200px;"/>

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## 1.1. Data as a combination of sinusoids

# %%
import numpy as np
import h5py
import pandas as pd
import scipy.signal
from matplotlib import pyplot as plt
from scipy.fftpack import fft
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import HoverTool
import pandas as pd
from bokeh.plotting import figure, show

Fs = 100
T = 1/Fs
sample = 5000
x = np.arange(sample)
t = np.arange(sample)/Fs
a1 = 3
f1 = 2
y1 = a1 * np.sin(2 * np.pi * f1 * x / Fs)

a2 = 1
f2 = 20
y2 = a2 * np.sin(2 * np.pi * f2 * x / Fs)

y = y1 + y2 


start = 0
end = 200

df = pd.DataFrame()
df['t'] = t[start:end]
df['y1'] = y1[start:end]
df['y2'] = y2[start:end]
df['y'] = y[start:end]

# %%
output_notebook()
p = figure(plot_width=800, plot_height=250)
p.title.text = 'Signals as combinations of sinusoids'

p.line(df['t'], df['y1'] , line_width=2, alpha=0.8, legend='y1,(Fs=2Hz, A=3)', line_color="blue")
p.line(df['t'], df['y2'] , line_width=2, alpha=0.8, legend='y2,(Fs=20Hz, A=1)', line_color="green")
p.line(df['t'], df['y'] , line_width=2, alpha=0.8, legend='y, (y1 + y2)', line_color="red")
    
p.legend.location = "top_left"
p.legend.click_policy="hide"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d91f6151-2929-4267-9978-0f50eebff05d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d74b602e-1f54-4b0e-80d9-2050f050c7a1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d74b602e-1f54-4b0e-80d9-2050f050c7a1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d74b602e-1f54-4b0e-80d9-2050f050c7a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd74b602e-1f54-4b0e-80d9-2050f050c7a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7e450a1b-c50d-407e-ab6d-0346d8c03bc5":{"roots":{"references":[{"attributes":{"label":{"value":"y, (y1 + y2)"},"renderers":[{"id":"6429ca66-870e-486d-8bc4-61ab1ffd6703","type":"GlyphRenderer"}]},"id":"01e74a53-6ed9-440b-b31e-6600352a6bcb","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"25e28ec3-3e26-4dd2-ad56-5466eba55664","type":"Line"},{"attributes":{},"id":"a59777e1-259f-4672-af2f-b856ced3039c","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ce782e1-c841-44d2-9242-b2f1efe79b84","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"
type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fcbec397-dca9-4f37-bc66-3a70a40e5f33","type":"Line"},"selection_glyph":null},"id":"e229259f-02b5-466c-8267-c54aa7a000c7","type":"GlyphRenderer"},{"attributes":{},"id":"8e1615b1-97fe-4b06-b2fc-94a4baf77cc8","type":"BasicTicker"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"62fbd924-0754-4203-8355-cd59e756fabc","type":"BasicTickFormatter"},"plot":{"id":"fa9e6b01-c9a6-474b-859c-7e1c055cd2db","subtype":"Figure","type":"Plot"},"ticker":{"id":"8e1615b1-97fe-4b06-b2fc-94a4baf77cc8","type":"BasicTicker"}},"id":"139ceaa4-f34e-4a00-9512-8a43f409efb2","type":"LinearAxis"},{"attributes":{"callback":null},"id":"53e0a424-a5ee-426f-b4d6-ef2c51730585","type":"DataRange1d"},{"attributes":{},"id":"68f3df88-961a-4d73- ...
#             var render_items = [{"docid":"261a9d70-90bc-449a-b35f-bcd05c86119b","elementid":"e75ea5c3-1ab7-4e8d-9

# %% [markdown]
# ### Real Data

# %%
#f = h5py.File("/Users/rishabhgupta/Downloads/2495.hdf5", "r")
f = h5py.File("./data/ecg_test.hdf5", "r")

ecg = np.array(f['/signals/ecg'])
Fs_ecg = 200
T_ecg = 1/Fs_ecg
start = 0
end = 120000
t = np.arange(np.size(ecg,0))/Fs_ecg

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
N = np.size(ecg,0)
yf = fft(ecg[:,1])
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="58d1fce9-b815-4922-b213-0fafc883b635">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cb0d79ab-80d3-4165-a5cc-e0d4a7889061"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cb0d79ab-80d3-4165-a5cc-e0d4a7889061");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cb0d79ab-80d3-4165-a5cc-e0d4a7889061");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cb0d79ab-80d3-4165-a5cc-e0d4a7889061' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b0c06778-4c51-49b7-bea2-532e60d43417":{"roots":{"references":[{"attributes":{"below":[{"id":"abf4da56-9692-4a65-8503-300bd8421692","type":"LinearAxis"}],"left":[{"id":"e8869305-483e-496a-af20-a8fc37adfdec","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"abf4da56-9692-4a65-8503-300bd8421692","type":"LinearAxis"},{"id":"2d323727-8094-4503-a0e2-c0ad7a520f25","type":"Grid"},{"id":"e8869305-483e-496a-af20-a8fc37adfdec","type":"LinearAxis"},{"id":"01044d89-70d9-46b0-a0c3-ac2864152fad","type":"Grid"},{"id":"5c514ce8-697d-4e42-9d83-9fc37446b58d","type":"GlyphRenderer"}],"title":{"id":"f3472c4e-69fe-433c-8a42-c24ec1ba664f","type":"Title"},"tool_events":{"id":"bec4d835-c533-4684-8166-74a3cd8713d3","type":"ToolEvents"},"toolbar":{"id":"8d1c6285-c7f4-4a24-bc0f-72f01d1626e2","type":"Toolbar"},"x_range":{"id":"dfe8ea9d-d884-4e8d-ae5a-3a97e0807378","type":"DataRange1d"},"y_range":{"id":"da44e784-9652-4d52-b742-18beb47e437a","type":"DataRange1d"}},"id":"8771d535-9c61-461d-acff-41bedc71f2ff","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"387640a1-bde8-4457-8942-8d2cf82e06a8","type":"Line"},{"attributes":{"callback":null},"id":"da44e784-9652-4d52-b742-18beb47e437a","type":"DataRange1d"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"6a913a96-aca9-4072-beb6-c51c63b70c35","type":"Line"},{"attributes":{},"id":"eb632a72-6365-485f-80e0-6c0721580f91","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6035]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6035]}}},"id":"568a975c-1f49-4d69-983a-310b1588d4ec","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"37250666-bf27-4ecc-af6f-7005c10a650b","type":"HoverTool"}]},"id":"8d1c6285-c7f4-4a24-bc0f-72f01d1626e2","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"8771d535-9c61-461d-acff-41bedc71f2ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb632a72-6365-485f-80e0-6c0721580f91","type":"BasicTicker"}},"id":"01044d89-70d9-46b0-a0c3-ac2864152fad","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"f3472c4e-69fe-433c-8a42-c24ec1ba664f","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"8771d535-9c61-461d-acff-41bedc71f2ff","subtype":"Figure","type":"Plot"},"tooltips":[["(Frequency,Amplitude)","($x, $y)"]]},"id":"37250666-bf27-4ecc-af6f-7005c10a650b","type":"HoverTool"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"50adeae7-aab7-4ea9-9b1d-2ab5a5aef85e","type":"BasicTickFormatter"},"plot":{"id":"8771d535-9c61-461d-acff-41bedc71f2ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"36b84021-3949-46e6-a175-7a498c8bab87","type":"BasicTicker"}},"id":"abf4da56-9692-4a65-8503-300bd8421692","type":"LinearAxis"},{"attributes":{},"id":"36b84021-3949-46e6-a175-7a498c8bab87","type":"BasicTicker"},{"attributes":{},"id":"bec4d835-c533-4684-8166-74a3cd8713d3","type":"ToolEvents"},{"attributes":{"callback":null},"id":"dfe8ea9d-d884-4e8d-ae5a-3a97e0807378","type":"DataRange1d"},{"attributes":{"plot":{"id":"8771d535-9c61-461d-acff-41bedc71f2ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"36b84021-3949-46e6-a175-7a498c8bab87","type":"BasicTicker"}},"id":"2d323727-8094-4503-a0e2-c0ad7a520f25","type":"Grid"},{"attributes":{"data_source":{"id":"568a975c-1f49-4d69-983a-310b1588d4ec","type":"ColumnDataSource"},"glyph":{"id":"6a913a96-aca9-4072-beb6-c51c63b70c35","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"387640a1-bde8-4457-8942-8d2cf82e06a8","type":"Line"},"selection_glyph":null},"id":"5c514ce8-697d-4e42-9d83-9fc37446b58d","type":"GlyphRenderer"},{"attributes":{},"id":"ae6a337e-c505-4e0b-a73c-c182ecfdf815","type":"BasicTickFormatter"},{"attributes":{},"id":"50adeae7-aab7-4ea9-9b1d-2ab5a5aef85e","type":"BasicTickFormatter"} ...
#             var render_items = [{"docid":"b0c06778-4c51-49b7-bea2-532e60d43417","elementid":"cb0d79ab-80d3-4165-a

# %% [markdown]
# ## 1.2. Filtering
#
# ### Removing unwanted information (frequencies) from the signal using filters
#
# <img src="img/filter.png" style="width: 500px;"/>

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ### High Pass Filter

# %%
N = 2 # Filter Order
cutoff = 5
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'high') # Butterworth filter - highpass
hp_filtered_ecg = scipy.signal.filtfilt(b, a, ecg[:,1])
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Low Pass Filter

# %%
N = 2 # Filter Order
cutoff = 30
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'low') # Butterworth filter - lowpass
lp_hp_filtered_ecg = scipy.signal.filtfilt(b, a, hp_filtered_ecg)
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], lp_hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Fourier Transform of the filtered signal

# %%
N = np.size(lp_hp_filtered_ecg,0)
yf = fft(lp_hp_filtered_ecg)
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8c44c11b-1d58-4884-83c6-040286535497">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aa3db68c-f0ad-4d45-8d1e-48c2ddb459a5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aa3db68c-f0ad-4d45-8d1e-48c2ddb459a5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aa3db68c-f0ad-4d45-8d1e-48c2ddb459a5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aa3db68c-f0ad-4d45-8d1e-48c2ddb459a5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0a223467-b5f9-4f7d-aa16-f6ceb60d9eac":{"roots":{"references":[{"attributes":{"below":[{"id":"a59b72ae-594b-4f9a-9c29-d6bb90dd249a","type":"LinearAxis"}],"left":[{"id":"bac5937d-c01e-457a-adba-d3a5a2cd8327","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"a59b72ae-594b-4f9a-9c29-d6bb90dd249a","type":"LinearAxis"},{"id":"4f690e02-d43b-489e-b443-8d09d95bd981","type":"Grid"},{"id":"bac5937d-c01e-457a-adba-d3a5a2cd8327","type":"LinearAxis"},{"id":"d9390371-471e-48de-a058-fe428478f589","type":"Grid"},{"id":"b9b73e06-a4a3-4882-8b6c-9a1066e081ca","type":"GlyphRenderer"}],"title":{"id":"45b6cec8-ffc7-49a7-b0f6-0852f698d1d0","type":"Title"},"tool_events":{"id":"7eecef2c-cbb6-4b5e-bd8e-ca2971bbc496","type":"ToolEvents"},"toolbar":{"id":"0410df89-8b4c-474e-9de3-3c0cb04af58b","type":"Toolbar"},"x_range":{"id":"37b5e353-52fd-4d53-b17e-48fda19d6cb7","type":"DataRange1d"},"y_range":{"id":"f6b47322-0c70-49e9-aae4-13e6d6995dfa","type":"DataRange1d"}},"id":"d5acc16d-61f0-4b0b-9edd-8ad525fc9c5f","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d5acc16d-61f0-4b0b-9edd-8ad525fc9c5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"22b0210f-aaa3-4508-8774-f262cb23946a","type":"BasicTicker"}},"id":"4f690e02-d43b-489e-b443-8d09d95bd981","type":"Grid"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"ab39e014-6436-4ae7-bb0e-e9c40d637701","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6035]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6035]}}},"id":"68b421d9-c943-4473-81d7-85d834d0e2e7","type":"ColumnDataSource"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"2a23b802-ff71-4ffb-a6ed-d24c48c2d798","type":"BasicTickFormatter"},"plot":{"id":"d5acc16d-61f0-4b0b-9edd-8ad525fc9c5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"22b0210f-aaa3-4508-8774-f262cb23946a","type":"BasicTicker"}},"id":"a59b72ae-594b-4f9a-9c29-d6bb90dd249a","type":"LinearAxis"},{"attributes":{},"id":"2a23b802-ff71-4ffb-a6ed-d24c48c2d798","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"45b6cec8-ffc7-49a7-b0f6-0852f698d1d0","type":"Title"},{"attributes":{},"id":"d0633db1-c635-4245-969c-3951bad00bcc","type":"BasicTickFormatter"},{"attributes":{},"id":"22b0210f-aaa3-4508-8774-f262cb23946a","type":"BasicTicker"},{"attributes":{},"id":"7eecef2c-cbb6-4b5e-bd8e-ca2971bbc496","type":"ToolEvents"},{"attributes":{"callback":null},"id":"37b5e353-52fd-4d53-b17e-48fda19d6cb7","type":"DataRange1d"},{"attributes":{},"id":"ec716f3d-ae20-4bc9-8dbf-5db949c2933a","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"07b66595-e47e-4d15-b7fe-10b0fd56a3a8","type":"HoverTool"}]},"id":"0410df89-8b4c-474e-9de3-3c0cb04af58b","type":"Toolbar"},{"attributes":{"axis_label":"Amplitude","formatter":{"id":"d0633db1-c635-4245-969c-3951bad00bcc","type":"BasicTickFormatter"},"plot":{"id":"d5acc16d-61f0-4b0b-9edd-8ad525fc9c5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec716f3d-ae20-4bc9-8dbf-5db949c2933a","type":"BasicTicker"}},"id":"bac5937d-c01e-457a-adba-d3a5a2cd8327","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"d5acc16d-61f0-4b0b-9edd-8ad525fc9c5f","subtype":"Figure","type":"Plot"},"tooltips":[["(Frequency,Amplitude)","($x, $y)"]]},"id":"07b66595-e47e-4d15-b7fe-10b0fd56a3a8","type":"HoverTool"},{"attributes":{"data_source":{"id":"68b421d9-c943-4473-81d7-85d834d0e2e7","type":"ColumnDataSource"},"glyph":{"id":"ab39e014-6436-4ae7-bb0e-e9c40d637701","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5ff4ac8e-9687-414f-bf44-d55a6ec631d2","type":"Line"},"selection_glyph":null},"id":"b9b73e06-a4a3-4882-8b6c-9a1066e081ca","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"f6b47322-0c70-49e9-aae4-13e6d6995dfa","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"d5acc16d-61f0-4b0b-9edd- ...
#             var render_items = [{"docid":"0a223467-b5f9-4f7d-aa16-f6ceb60d9eac","elementid":"aa3db68c-f0ad-4d45-8

# %% [markdown]
# # 2. Feature Construction

# %%
from matplotlib import pyplot as plt
import pandas as pd
import scipy.signal 
import time
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (8,8)
df = pd.read_csv("./data/sg1.csv", header=None)
df = df.T
k = df.as_matrix(columns=None)

# %%
plt.plot(k[1][0:],'b-')
plt.show()

# %% [markdown]
# # 3. Feature Selection

# %%
df = pd.read_csv("./data/sg2.csv", header=None)
df = df.T
k2 = df.as_matrix(columns=None)

# %%
plt.subplot(1, 2, 1)
plt.plot(k[1][0:],'b-')
plt.subplot(1, 2, 2)
plt.plot(k2[1][0:],'r-')
plt.show()

# %% [markdown]
# # 4. Model Development

# %% [markdown]
# ## Regression Model
#
# ##### Fit a line through data points
#
# <img src="img/reg1.png" style="width: 500px;"/>

# %% [markdown]
# ##### Make predictions based on the fitted line
#
# <img src="img/reg2.png" style="width: 500px;"/>

# %% [markdown]
# # How do we use regression in SKIIN?

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
# Regression with synthetic data
# Data
# Heart rate
hr = np.sort(np.random.randint(60, high=120, size=500))
# Stress: 0 - 1
st = np.sort(np.random.rand(500))

# %%
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.show()

# %% [markdown]
# ## Use Least Square Estimation to fit a line
#
# ##### Equation of a line: $ y = \beta_{0}  x + \beta_{1} $
#
# ##### $\beta_{0}$ and $\beta_{1}$ are the slope and intercepts of the line
#
# ##### $\beta_{0}$ and $\beta_{1}$ are also model parameters which need to be estimated
#
# ##### Least squares formula: $ \beta = (X^{-1}X)X'Y$

# %% [markdown]
# ## Least Squares Derivation
#
# <img src="img/ls_derive.png" style="width: 400px;"/>

# %%
# Estimating the coefficient and intercept using linear algebra
# Using the equation beta = inv(x'x)x'y
y = np.matrix(st)
x = np.matrix(np.column_stack(
    (hr, np.ones(len(st)))))
b = np.linalg.inv(x.T * x) * x.T * y.T

# The coefficient and intercept estimated from matrix multiplication
beta_prime_coef = b[0]
beta_prime_intrp = b[1]

y_prime = x * b

# %%
print('The equation for the line is: Stress = ' + str(b[0]) + ' * Heart Rate + ' + str(b[1]))
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.plot(hr, y_prime, '--')
plt.show()
# Out:
# The equation for the line is: Stress = [[ 0.01669321]] * Heart Rate + [[-0.98673883]]

# %% [markdown]
# ## Classification Model
#
# <img src="img/classification.png" style="width: 400px;"/>

# %% [markdown]
# ## How can we use classification model for SKIIN?

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from math import ceil, floor
from sklearn.metrics import accuracy_score
n_samples = 1000
# Mean HR
hr_1 = np.random.normal(60, 20, size=n_samples)
hr_2 = np.random.normal(80, 10, size=n_samples)

# Average minutes they worked out during the day
st_1 = np.random.normal(120, 20, n_samples)
st_2 = np.random.normal(30, 20, n_samples) + 1

# %%
# Plotting the data
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.show()

# %% [markdown]
# ## Least Squares Estimation of Model Parameters

# %%
# Binary classification
# Healthy class = -1
class_1 = -1*np.ones(len(hr_1))
# Unhealthy class = 1
class_2 =  np.ones(len(hr_2))

# Training data
feat_mat1 = np.column_stack((hr_1, st_1, class_1))
feat_mat2 = np.column_stack((hr_2, st_2, class_2))

X_temp = np.vstack((feat_mat1, feat_mat2))
np.random.shuffle(X_temp)

X_train = X_temp[:, 0:2]
Y_train = X_temp[:, 2]

X_trr = np.column_stack((X_train, np.ones(len(X_train))))
dot1 = np.linalg.inv(np.dot(X_trr.T, X_trr)) 
dot2 = np.dot(dot1,X_trr.T)
b_ls = np.dot(dot2,Y_train.T)


# Range of X-axis for the hyperplane
m_1_x = floor(np.min(X_train[:, 0]))
m_2_x = ceil(np.max(X_train[:, 0]))
x_ax = np.arange(m_1_x, m_2_x+1)

y_ls = np.zeros(len(x_ax))
for k in range(0, len(y_ls)):   
    y_ls[k] = -x_ax[k]*(b_ls[0]/b_ls[1]) - (b_ls[2]/b_ls[1])

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')
plt.show()

# %% [markdown]
# # Perceptron approach for computing model parameters

# %%
# Initialize
w = np.zeros(len(X_train[0,0:2]))
b = 0
for k in range(0, len(X_train)):
    if np.sign(np.dot(w, X_train[k, :]) + b) != Y_train[k]:
        w = w + Y_train[k] * X_train[k, :]
        b = b + Y_train[k]

y_p = np.zeros(len(x_ax))
for k in range(0, len(y_p)):
    y_p[k] = -1*x_ax[k]*w[0]/w[1] - b/w[1]

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')    
plt.plot(x_ax, y_p,'r')
plt.show()

# %% [markdown]
# # Conclusion
#
# ##### You learnt how to remove noise from the data
#
# ##### You learnt how to construct features
#
# ##### You learnt how to select features for classification/regression
#
# ##### You learnt how to develop regression and classification models

# %% [markdown]
# # Questions??
