# %% [markdown]
# # Introduction to Machine Learning
#
# ## By Data Science Team at Myant

# %% [markdown]
# # What is Machine Learning?
#
# ##### Concept that deals with study and construction of systems that:
# * Extract meaning from data
# * Learn from data
#
#
# <img src="img/ecg.png" style="width: 400px;"/>

# %% [markdown]
# # Why use Machine Learning?
#
# ##### Mimic humans and replace monotonous tasks. Example: self-driven cars, SKIIN signal quality estimators
#
# ##### Systems that automatically adapt and customize to users. Example: recommender systems of Netflix, Spotify etc,
#
# ##### Natural language processing. Example: sentiment analysis algorithms of Twitter
#
# ##### Other examples: Prisma filters on Instagram, Deep dreams featured in Cold Ft. Future by Maroon 5

# %% [markdown]
# <img src="img/deepdreams.png" style="width: 800px;"/>

# %% [markdown]
# # How to make a machine learn new information?
#
# <img src="img/ml2.jpg" style="width: 800px;"/>

# %% [markdown]
# # Types of Machine Learning
# ##### Supervised: correct classes of training data are known.
# * Regression
# * Classification
#
# ##### Unsupervised: correct classes of training  data are unknown.
# * Clustering
# <img src="img/regclassclus.png" style="width: 500px;"/>

# %% [markdown]
# ##### Reinforcement learning: system learns its behaviour based on feedback from enviroment
#
# [Google's DeepMind](https://www.youtube.com/watch?v=gn4nRCC9TwQ "link title")

# %% [markdown]
# # Typical Machine Learning Pipeline
# <img src="img/mlpipeline.png" style="width:1200px;"/>

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## 1.1. Data as a combination of sinusoids

# %%
import numpy as np
import h5py
import pandas as pd
import scipy.signal
from matplotlib import pyplot as plt
from scipy.fftpack import fft
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import HoverTool
import pandas as pd
from bokeh.plotting import figure, show

Fs = 100
T = 1/Fs
sample = 5000
x = np.arange(sample)
t = np.arange(sample)/Fs
a1 = 3
f1 = 2
y1 = a1 * np.sin(2 * np.pi * f1 * x / Fs)

a2 = 1
f2 = 20
y2 = a2 * np.sin(2 * np.pi * f2 * x / Fs)

y = y1 + y2 


start = 0
end = 200

df = pd.DataFrame()
df['t'] = t[start:end]
df['y1'] = y1[start:end]
df['y2'] = y2[start:end]
df['y'] = y[start:end]

# %%
output_notebook()
p = figure(plot_width=800, plot_height=250)
p.title.text = 'Signals as combinations of sinusoids'

p.line(df['t'], df['y1'] , line_width=2, alpha=0.8, legend='y1,(Fs=2Hz, A=3)', line_color="blue")
p.line(df['t'], df['y2'] , line_width=2, alpha=0.8, legend='y2,(Fs=20Hz, A=1)', line_color="green")
p.line(df['t'], df['y'] , line_width=2, alpha=0.8, legend='y, (y1 + y2)', line_color="red")
    
p.legend.location = "top_left"
p.legend.click_policy="hide"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19ba5590-e9b2-4989-871c-0e160fc90aba">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ec18b7f5-13f6-4e01-9b13-e27e5b0c502f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ec18b7f5-13f6-4e01-9b13-e27e5b0c502f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ec18b7f5-13f6-4e01-9b13-e27e5b0c502f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ec18b7f5-13f6-4e01-9b13-e27e5b0c502f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2cee820b-ced7-4b65-81e9-09f2d85c3877":{"roots":{"references":[{"attributes":{"plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"}},"id":"92f510d7-fc6f-4e75-97e2-e71833714c3a","type":"PanTool"},{"attributes":{},"id":"f5289a5b-627b-42b9-ae3e-39751857b49c","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"value":"green"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"51caaeca-b20a-4df1-acc4-7b196dae6110","type":"Line"},{"attributes":{"data_source":{"id":"416b2f50-9703-4821-babd-d8eb0f3cc3e2","type":"ColumnDataSource"},"glyph":{"id":"09d72f5f-13dc-4aa9-9203-35a7bb49cc5f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5349d763-034b-4511-9a61-539dc1295968","type":"Line"},"selection_glyph":null},"id":"bdcc3a2a-deda-42f9-8d30-d71919c95531","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"949be718-16b0-4522-bc70-419dd9244548","type":"BasicTickFormatter"},"plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5289a5b-627b-42b9-ae3e-39751857b49c","type":"BasicTicker"}},"id":"a540b65e-e530-47eb-9a4c-76f472bcfce1","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5289a5b-627b-42b9-ae3e-39751857b49c","type":"BasicTicker"}},"id":"04e9074d-cd2e-4dde-b31d-d5f02510e26e","type":"Grid"},{"attributes":{"callback":null},"id":"10046775-0913-4662-a703-90f4c3ea3412","type":"DataRange1d"},{"attributes":{"label":{"value":"y, (y1 + y2)"},"renderers":[{"id":"67ec3ecf-4eaa-4c2b-9f8b-2dda40ad125c","type":"GlyphRenderer"}]},"id":"9429e4e7-e421-4115-8d9e-ee3751e1177f","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"03d863d9-8515-44d1-a3f8-deb21e1fb670","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"}},"id":"acaf7d6c-eb0c-4881-a780-6f2714fb0f36","type":"WheelZoomTool"},{"attributes":{"click_policy":"hide","items":[{"id":"7fa0f871-94c3-454b-b5cd-7648933cb8b3","type":"LegendItem"},{"id":"9c96863c-5f2a-438e-95bd-03cbfc8e91f5","type":"LegendItem"},{"id":"9429e4e7-e421-4115-8d9e-ee3751e1177f","type":"LegendItem"}],"location":"top_left","plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"}},"id":"66ba62c1-b942-4673-98e6-fc7d87afba4e","type":"Legend"},{"attributes":{"plot":null,"text":"Signals as combinations of sinusoids"},"id":"1d9fc44e-6167-493a-884c-51dfc8eb77f7","type":"Title"},{"attributes":{},"id":"2e1acc38-e02c-4dc1-9dc7-c0fc5ae60996","type":"BasicTicker"},{"attributes":{},"id":"680ab8b8-e1ef-48fa-9af8-e8cfe7711934","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c24e9993-9c04-42b9-ac62-f408211b102a","type":"Line"},{"attributes":{"plot":{"id":"bf7436dd-f3a9-4abe-9cfc-b2dc975642a7","subtype":"Figure","type":"Plot"}},"id":"150220b0-511e-4eb2-a489-71d467c74a48","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"a300fe97-4c53-40d5-b74f-8eb10e4b4ad0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a300fe97-4c53-40d5-b74f-8eb10e4b4ad0","type":"ColumnDataSource"},"glyph":{"id":"51caaeca-b20a-4df1-acc4-7b196dae6110","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c24e9993-9c04-42b9-ac62-f408211b102a","type":"Line"},"selection_glyph":null},"id":"853029f7-68dc-4885-810d-9bc51021ed05","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"23395727-0ad5-4657-8a2d-075eacb4735 ...

# %% [markdown]
# ### Fourier Transform
#
# ##### Technique to decompose a signal into different sinusoids.

# %% [markdown]
# $X_k = \sum_{n=0}^{N-1} x_n e^{-i2\pi kn/N}$

# %%
N = sample
yf = fft(y)
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="44c3fcda-5996-4dd6-9667-23397b5866be">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5643dac3-1664-4977-9339-d9346a4cbfc5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5643dac3-1664-4977-9339-d9346a4cbfc5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
},{"attributes":{"axis_label":"Amplitude","formatter":{"id":"5c87b012-41c6-4882-a19d-ac526ab41f96","type":"BasicTickFormatter"},"plot":{"id":"fa6812a5-3694-4cb3-b6ff-dabef4fdb3e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"96f4b43c-13f1-408f-a14d-31ffcbb24b1d","type":"BasicTicker"}},"id":"1d53e923-58df-4564-9082-35d1afc3db04","type":"LinearAxis"},{"attributes":{},"id":"3e844802-9bc7-4a5d-902e-2fc8f089 ...
#             var render_items = [{"docid":"6a112048-9b04-4586-ba3e-97cb6310cf4e","elementid":"5643dac3-1664-4977-9

# %% [markdown]
# ### Real Data

# %%
#f = h5py.File("/Users/rishabhgupta/Downloads/2495.hdf5", "r")
f = h5py.File("./data/ecg_test.hdf5", "r")

ecg = np.array(f['/signals/ecg'])
Fs_ecg = 200
T_ecg = 1/Fs_ecg
start = 0
end = 120000
t = np.arange(np.size(ecg,0))/Fs_ecg

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
N = np.size(ecg,0)
yf = fft(ecg[:,1])
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d934b3c-6b28-4d01-8edd-4ac0bed4e54f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6264865-b553-4211-92cb-0ea883f047ec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d6264865-b553-4211-92cb-0ea883f047ec");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6264865-b553-4211-92cb-0ea883f047ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6264865-b553-4211-92cb-0ea883f047ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c6109736-7004-4f2a-b83e-79125549dfe3":{"roots":{"references":[{"attributes":{},"id":"8b1a84a5-4890-4735-895d-4fe73371f236","type":"ToolEvents"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"52f405d0-61d0-4192-8785-c2ad92b9433c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0159b5f3-f7ed-47b7-832e-758d0eca95f9","type":"Line"},{"attributes":{"callback":null},"id":"3d5d8bf9-eb2c-4355-8add-fbb8e95b3a8d","type":"DataRange1d"},{"attributes":{},"id":"bd378f79-76d6-4854-a532-9e6ec69b4590","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"151b575d-23b1-4418-9130-df73f083099c","type":"HoverTool"}]},"id":"f88965a9-4080-4180-88ed-f5e099931bf0","type":"Toolbar"},{"attributes":{},"id":"7cb63e1f-972d-4618-b286-4e903bd08cf0","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"2158409f-68ad-4e6c-91b3-b771ed62d131","type":"Title"},{"attributes":{"below":[{"id":"70837b64-0dfa-4047-b59b-01d49ee18ede","type":"LinearAxis"}],"left":[{"id":"05ab48b0-9cf8-40f2-9a9e-4c6c3a42f5c6","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"70837b64-0dfa-4047-b59b-01d49ee18ede","type":"LinearAxis"},{"id":"496b4cce-169f-445d-823f-1e7c868c9774","type":"Grid"},{"id":"05ab48b0-9cf8-40f2-9a9e-4c6c3a42f5c6","type":"LinearAxis"},{"id":"dc3e5e93-b497-4690-b63e-a555723c0af3","type":"Grid"},{"id":"13d8cc92-b4af-4e69-8a5a-83d97d937163","type":"GlyphRenderer"}],"title":{"id":"2158409f-68ad-4e6c-91b3-b771ed62d131","type":"Title"},"tool_events":{"id":"8b1a84a5-4890-4735-895d-4fe73371f236","type":"ToolEvents"},"toolbar":{"id":"f88965a9-4080-4180-88ed-f5e099931bf0","type":"Toolbar"},"x_range":{"id":"ec184a06-a3a5-4bb0-bf09-42f1fac08f63","type":"DataRange1d"},"y_range":{"id":"3d5d8bf9-eb2c-4355-8add-fbb8e95b3a8d","type":"DataRange1d"}},"id":"85fdc344-d2ec-4826-8eb2-6d86220ff3da","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e62b8397-ef5d-4a6b-a929-3b1209d836e9","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"ec184a06-a3a5-4bb0-bf09-42f1fac08f63","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"85fdc344-d2ec-4826-8eb2-6d86220ff3da","subtype":"Figure","type":"Plot"},"tooltips":[["(Frequency,Amplitude)","($x, $y)"]]},"id":"151b575d-23b1-4418-9130-df73f083099c","type":"HoverTool"},{"attributes":{"data_source":{"id":"23309c73-4350-411e-8703-d8c5ed5c50d1","type":"ColumnDataSource"},"glyph":{"id":"52f405d0-61d0-4192-8785-c2ad92b9433c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0159b5f3-f7ed-47b7-832e-758d0eca95f9","type":"Line"},"selection_glyph":null},"id":"13d8cc92-b4af-4e69-8a5a-83d97d937163","type":"GlyphRenderer"},{"attributes":{"axis_label":"Amplitude","formatter":{"id":"7cb63e1f-972d-4618-b286-4e903bd08cf0","type":"BasicTickFormatter"},"plot":{"id":"85fdc344-d2ec-4826-8eb2-6d86220ff3da","subtype":"Figure","type":"Plot"},"ticker":{"id":"d327046a-aa79-4c7c-9a49-7253523e59af","type":"BasicTicker"}},"id":"05ab48b0-9cf8-40f2-9a9e-4c6c3a42f5c6","type":"LinearAxis"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"e62b8397-ef5d-4a6b-a929-3b1209d836e9","type":"BasicTickFormatter"},"plot":{"id":"85fdc344-d2ec-4826-8eb2-6d86220ff3da","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd378f79-76d6-4854-a532-9e6ec69b4590","type":"BasicTicker"}},"id":"70837b64-0dfa-4047-b59b-01d49ee18ede","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6035]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6035]}}},"id":"23309c73-4350-411e-8703-d8c5ed5c50d1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"85fdc344-d2ec-4826-8eb2-6d86220ff3da","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd378f79-76d6-4854-a532-9e6ec69b4590","type":"BasicTicker"}},"id":"496b4cce-169f-445d-823f-1e7c868c ...
#             var render_items = [{"docid":"c6109736-7004-4f2a-b83e-79125549dfe3","elementid":"d6264865-b553-4211-9

# %% [markdown]
# ## 1.2. Filtering
#
# ### Removing unwanted information (frequencies) from the signal using filters
#
# <img src="img/filter.png" style="width: 500px;"/>

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ### High Pass Filter

# %%
N = 2 # Filter Order
cutoff = 5
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'high') # Butterworth filter - highpass
hp_filtered_ecg = scipy.signal.filtfilt(b, a, ecg[:,1])
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Low Pass Filter

# %%
N = 2 # Filter Order
cutoff = 30
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'low') # Butterworth filter - lowpass
lp_hp_filtered_ecg = scipy.signal.filtfilt(b, a, hp_filtered_ecg)
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], lp_hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Fourier Transform of the filtered signal

# %%
N = np.size(lp_hp_filtered_ecg,0)
yf = fft(lp_hp_filtered_ecg)
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="adb8e685-45ab-46c4-9865-cd1a1af8ebe5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="17835fbb-25c2-41c9-aaab-c3fde38693bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("17835fbb-25c2-41c9-aaab-c3fde38693bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("17835fbb-25c2-41c9-aaab-c3fde38693bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '17835fbb-25c2-41c9-aaab-c3fde38693bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9591e70a-8e6f-45e2-a612-27aadb4e886d":{"roots":{"references":[{"attributes":{"plot":{"id":"a8743698-b90a-447f-b331-873a031f40d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"7
type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6035]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6035]}}},"id":"13f34d29-58d5-4f5a-85f3-0261fb74bdcf","type":"ColumnDataSource"},{"at ...
#             var render_items = [{"docid":"9591e70a-8e6f-45e2-a612-27aadb4e886d","elementid":"17835fbb-25c2-41c9-a

# %% [markdown]
# # 2. Feature Construction

# %%
from matplotlib import pyplot as plt
import pandas as pd
import scipy.signal 
import time
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (8,8)
df = pd.read_csv("./data/sg1.csv", header=None)
df = df.T
k = df.as_matrix(columns=None)

# %%
plt.plot(k[1][0:],'b-')
plt.show()

# %% [markdown]
# # 3. Feature Selection

# %%
df = pd.read_csv("./data/sg2.csv", header=None)
df = df.T
k2 = df.as_matrix(columns=None)

# %%
plt.subplot(1, 2, 1)
plt.plot(k[1][0:],'b-')
plt.subplot(1, 2, 2)
plt.plot(k2[1][0:],'r-')
plt.show()

# %% [markdown]
# # 4. Model Development

# %% [markdown]
# ## Regression Model
#
# ##### Fit a line through data points
#
# <img src="img/reg1.png" style="width: 500px;"/>

# %% [markdown]
# ##### Make predictions based on the fitted line
#
# <img src="img/reg2.png" style="width: 500px;"/>

# %% [markdown]
# # Example: How do we use regression in SKIIN?

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
# Regression with synthetic data
# Data
# Heart rate
hr = np.sort(np.random.randint(60, high=120, size=500))
# Stress: 0 - 1
st = np.sort(np.random.rand(500))

# %%
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.show()

# %% [markdown]
# ## Use Least Square Estimation to fit a line
#
# ##### Equation of a line: $ y = \beta_{0}  x + \beta_{1} $
#
# ##### $\beta_{0}$ and $\beta_{1}$ are the slope and intercepts of the line
#
# ##### $\beta_{0}$ and $\beta_{1}$ are also model parameters which need to be estimated
#
# ##### Least squares formula: $ \beta = (X^{-1}X)X'Y$

# %% [markdown]
# ## Least Squares Derivation
#
# <img src="img/ls_derive.png" style="width: 400px;"/>

# %%
# Estimating the coefficient and intercept using linear algebra
# Using the equation beta = inv(x'x)x'y
y = np.matrix(st)
x = np.matrix(np.column_stack(
    (hr, np.ones(len(st)))))
b = np.linalg.inv(x.T * x) * x.T * y.T

# The coefficient and intercept estimated from matrix multiplication
beta_prime_coef = b[0]
beta_prime_intrp = b[1]

y_prime = x * b

# %%
print('The equation for the line is: Stress = ' + str(b[0]) + ' * Heart Rate + ' + str(b[1]))
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.plot(hr, y_prime, '--')
plt.show()
# Out:
# The equation for the line is: Stress = [[ 0.01677816]] * Heart Rate + [[-0.95607036]]

# %% [markdown]
# ## How can we use classification model for SKIIN?
#
# ##### Classify healthy and unhealthy people
#
# ##### Data from 60 people, 30 in each class over a period of 20 days
#
# ##### Data: total number of hours they worked out each day and mean heart rate for that day
#
# ##### Features: Avergae daily workout for each person, avergae heart rate on each day

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from math import ceil, floor
from sklearn.metrics import accuracy_score
n_samples = 1000
# Mean HR
hr_1 = np.random.normal(60, 20, size=n_samples)
hr_2 = np.random.normal(100, 10, size=n_samples)

# Average minutes they worked out during the day
st_1 = np.random.normal(120, 20, n_samples)
st_2 = np.random.normal(50, 20, n_samples) + 1

# %%
# Plotting the data
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.show()

# %% [markdown]
# ## Least Squares Estimation of Model Parameters or Training

# %%
# Binary classification
# Healthy class = -1
class_1 = -1*np.ones(len(hr_1))
# Unhealthy class = 1
class_2 =  np.ones(len(hr_2))

# Training data
feat_mat1 = np.column_stack((hr_1, st_1, class_1))
feat_mat2 = np.column_stack((hr_2, st_2, class_2))

X_temp = np.vstack((feat_mat1, feat_mat2))
np.random.shuffle(X_temp)

X_train = X_temp[0:-2, 0:2]
Y_train = X_temp[0:-2, 2]

X_test = X_temp[-1, 0:2]
Y_test = X_temp[-1, 2]

X_trr = np.column_stack((X_train, np.ones(len(X_train))))
dot1 = np.linalg.inv(np.dot(X_trr.T, X_trr)) 
dot2 = np.dot(dot1,X_trr.T)
b_ls = np.dot(dot2,Y_train.T)


# Range of X-axis for the hyperplane
m_1_x = floor(np.min(X_train[:, 0]))
m_2_x = ceil(np.max(X_train[:, 0]))
x_ax = np.arange(m_1_x, m_2_x+1)

y_ls = np.zeros(len(x_ax))
for k in range(0, len(y_ls)):   
    y_ls[k] = -x_ax[k]*(b_ls[0]/b_ls[1]) - (b_ls[2]/b_ls[1])

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')
plt.show()

# %% [markdown]
# # Testing
#
# ##### Mean heart rate = 85 bpm
#
# ##### Mean daily exercise time = 55 min

# %%
op = np.sign(b_ls[1] * 55 + b_ls[0] * 85)
print('The classifier output is: ' + str(op) + ', where 1 = unhealthy class & -1 = healthy class. ')
print('The expected output is: ' + str(1.0) + ', where 1 = unhealthy class & -1 = healthy class. ')
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.plot(85,55,'ko')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')
plt.show()
# Out:
# The classifier output is: 1.0, where 1 = unhealthy class & -1 = healthy class.
# The expected output is: 1.0, where 1 = unhealthy class & -1 = healthy class.

# %% [markdown]
# # Perceptron Architecture
#
#
# <img src="img/perceptron.png" style="width: 600px;"/>

# %% [markdown]
# # Biological Neuron
#
# <img src="img/biological_neuron.png" style="width: 600px;"/>

# %% [markdown]
# # Perceptron approach for computing model parameters

# %%
# Initialize
w = np.zeros(len(X_train[0,0:2]))
b = 0
for k in range(0, len(X_train)):
    if np.sign(np.dot(w, X_train[k, :]) + b) != Y_train[k]:
        w = w + Y_train[k] * X_train[k, :]
        b = b + Y_train[k]

y_p = np.zeros(len(x_ax))
for k in range(0, len(y_p)):
    y_p[k] = -1*x_ax[k]*w[0]/w[1] - b/w[1]

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')    
plt.plot(x_ax, y_p,'r')
plt.show()

# %% [markdown]
# # Artificial Neural Network (ANN)
#
# <img src="img/ann.png" style="width: 600px;"/>

# %% [markdown]
# # Deep Neural Network (DNN)
#
# <img src="img/dnn.png" style="width: 600px;"/>

# %% [markdown]
# # DNN Examples
#
# [DeepDrive OpenAI](https://www.youtube.com/watch?v=X4u2DCOLoIg "link title")
#
#
# [NVIDIA Demo](https://www.youtube.com/watch?v=0rc4RqYLtEU "link title")
#
#
#
# [WaveNet Demo](https://deepmind.com/blog/wavenet-launches-google-assistant/ "link title")

# %% [markdown]
# # Conclusion
#
# ##### You learnt how to remove noise from the data
#
# ##### You learnt how to construct features
#
# ##### You learnt how to select features for classification/regression
#
# ##### You learnt how to develop regression and classification models

# %% [markdown]
# # Questions??
