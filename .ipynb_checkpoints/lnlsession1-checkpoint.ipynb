# %% [markdown]
# # Introduction to Machine Learning
#
# ## By Data Science Team at Myant

# %% [markdown]
# # What is Machine Learning?
#
# ##### Concept that deals with study and construction of systems that:
# * Extract meaning from data
# * Learn from data
#
#
# <img src="img/ecg.png" style="width: 400px;"/>

# %% [markdown]
# # Why use Machine Learning?
#
# ##### Mimic humans and replace monotonous tasks. Example: self-driven cars, SKIIN signal quality estimators
#
# ##### Systems that automatically adapt and customize to users. Example: recommender systems of Netflix, Spotify etc,
#
# ##### Natural language processing. Example: sentiment analysis algorithms of Twitter
#
# ##### Other examples: Prisma filters on Instagram, Deep dreams featured in Cold Ft. Future by Maroon 5

# %% [markdown]
# <img src="img/deepdreams.png" style="width: 800px;"/>

# %% [markdown]
# # How to make a machine learn new information?
#
# <img src="img/ml2.jpg" style="width: 800px;"/>

# %% [markdown]
# # Types of Machine Learning
# ##### Supervised: correct classes of training data are known.
# * Regression
# * Classification
#
# ##### Unsupervised: correct classes of training  data are unknown.
# * Clustering
# <img src="img/regclassclus.png" style="width: 500px;"/>

# %% [markdown]
# ##### Reinforcement learning: system learns its behaviour based on feedback from enviroment
#
# [Google's DeepMind](https://www.youtube.com/watch?v=gn4nRCC9TwQ "link title")

# %% [markdown]
# # Typical Machine Learning Pipeline
# <img src="img/mlpipeline.png" style="width:1200px;"/>

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## 1.1. Data as a combination of sinusoids

# %%
import numpy as np
import h5py
import pandas as pd
import scipy.signal
from matplotlib import pyplot as plt
from scipy.fftpack import fft
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import HoverTool
import pandas as pd
from bokeh.plotting import figure, show

Fs = 100
T = 1/Fs
sample = 5000
x = np.arange(sample)
t = np.arange(sample)/Fs
a1 = 3
f1 = 2
y1 = a1 * np.sin(2 * np.pi * f1 * x / Fs)

a2 = 1
f2 = 20
y2 = a2 * np.sin(2 * np.pi * f2 * x / Fs)

y = y1 + y2 


start = 0
end = 200

df = pd.DataFrame()
df['t'] = t[start:end]
df['y1'] = y1[start:end]
df['y2'] = y2[start:end]
df['y'] = y[start:end]

# %%
output_notebook()
p = figure(plot_width=800, plot_height=250)
p.title.text = 'Signals as combinations of sinusoids'

p.line(df['t'], df['y1'] , line_width=2, alpha=0.8, legend='y1,(Fs=2Hz, A=3)', line_color="blue")
p.line(df['t'], df['y2'] , line_width=2, alpha=0.8, legend='y2,(Fs=20Hz, A=1)', line_color="green")
p.line(df['t'], df['y'] , line_width=2, alpha=0.8, legend='y, (y1 + y2)', line_color="red")
    
p.legend.location = "top_left"
p.legend.click_policy="hide"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bdf78ac9-8c94-48a9-8ecb-2f53810af43d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6d15fa2-1254-4dc4-b246-6a46d4c8467e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d6d15fa2-1254-4dc4-b246-6a46d4c8467e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6d15fa2-1254-4dc4-b246-6a46d4c8467e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6d15fa2-1254-4dc4-b246-6a46d4c8467e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c
type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"37fa470c-efba-4994-989c-428b8bd407cd","type":"BasicTickFormatter"},"plot":{"id":"42782da2-4d05-48ce-977c-ff639fff0040","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca51584d-d8dc-4594-9f20-b4e17bf5271d","type":"BasicTicker"}},"id":"36f27539-5e93-423d-be7e-ba1ed14ad21b","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"da77507a-60ec-4520-b747-4acb877ecb7 ...

# %% [markdown]
# ### Fourier Transform
#
# ##### Technique to decompose a signal into different sinusoids.

# %% [markdown]
# $X_k = \sum_{n=0}^{N-1} x_n e^{-i2\pi kn/N}$

# %%
N = sample
yf = fft(y)
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="02d42b7f-3087-43f2-97fb-3cc6764d8d57">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d4cce07-0981-4799-9568-abbceb4a1cd5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0d4cce07-0981-4799-9568-abbceb4a1cd5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d4cce07-0981-4799-9568-abbceb4a1cd5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d4cce07-0981-4799-9568-abbceb4a1cd5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"56475eb0-45ca-444e-8d3e-26ef7fdc551b":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"26df8f3f-30d6-47ec-ab67-9d86acb0a913","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"d8d22246-f787-4e9c-b336-9353aae96447","subtype":"Figure","type":"Plot"},"ticker":{"id":"786a7d0e-1ab7-4523-8a5e-735442502346","type":"BasicTicker"}},"id":"9e45aef0-9341-4c54-92af-f8ed974fd052","type":"Grid"},{"attributes":{"callback":null},"id":"613d6f39-918a-46cc-a52a-921ebc01ce29","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2500]}}},"id":"0d34c05d-8189-4c38-8fed-4d04728481ef","type":"ColumnDataSource"},{"attributes":{},"id":"786a7d0e-1ab7-4523-8a5e-735442502346","type":"BasicTicker"},{"attributes":{"axis_label":"Amplitude","formatter":{"id":"dceef8c5-8884-4d3f-b0ac-4bf7d80e1f24","type":"BasicTickFormatter"},"plot":{"id":"d8d22246-f787-4e9c-b336-9353aae96447","subtype":"Figure","type":"Plot"},"ticker":{"id":"786a7d0e-1ab7-4523-8a5e-735442502346","type":"BasicTicker"}},"id":"242f3e14-f95f-493b-a7ed-3dd9f4e571fc","type":"LinearAxis"},{"attributes":{},"id":"dceef8c5-8884-4d3f-b0ac-4bf7d80e1f24","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"1fcd1795-8d75-4612-aa3b-aba49e723618","type":"DataRange1d"},{"attributes":{},"id":"53b38c4c-704f-4f6d-91ee-a292e6b37004","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"94dc379c-96da-42ec-a53e-7de6dacb9420","type":"Title"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"fd31608c-5684-416d-bc4e-baac959002af","type":"Line"},{"attributes":{"plot":{"id":"d8d22246-f787-4e9c-b336-9353aae96447","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c25fc0f-b1e5-449e-8d58-1e5911c5c96b","type":"BasicTicker"}},"id":"f51e3729-476a-4321-8e44-8c5ea306d5ea","type":"Grid"},{"attributes":{},"id":"34899e93-dfd0-46c9-aa8e-096b526f3718","type":"ToolEvents"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"53b38c4c-704f-4f6d-91ee-a292e6b37004","type":"BasicTickFormatter"},"plot":{"id":"d8d22246-f787-4e9c-b336-9353aae96447","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c25fc0f-b1e5-449e-8d58-1e5911c5c96b","type":"BasicTicker"}},"id":"ebf31a4b-0d4c-498d-80a9-3fce6789eb4a","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"d8d22246-f787-4e9c-b336-9353aae96447","subtype":"Figure","type":"Plot"},"tooltips":[["(Frequency,Amplitude)","($x, $y)"]]},"id":"03a9a77e-baab-48bd-9c2e-aba8b2d643d1","type":"HoverTool"},{"attributes":{"data_source":{"id":"0d34c05d-8189-4c38-8fed-4d04728481ef","type":"ColumnDataSource"},"glyph":{"id":"fd31608c-5684-416d-bc4e-baac959002af","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"26df8f3f-30d6-47ec-ab67-9d86acb0a913","type":"Line"},"selection_glyph":null},"id":"1c149d9f-043d-46ad-93d4-c134caf56aa2","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"03a9a77e-baab-48bd-9c2e-aba8b2d643d1","type":"HoverTool"}]},"id":"de2654e5-d2d2-4715-a944-9fddcc77230e","type":"Toolbar"},{"attributes":{},"id":"1c25fc0f-b1e5-449e-8d58-1e5911c5c96b","type":"BasicTicker"},{"attributes":{"below":[{"id":"ebf31a4b-0d4c-498d-80a9-3fce6789eb4a","type":"LinearAxis"}],"left":[{"id":"242f3e14-f95f-493b-a7ed-3dd9f4e571fc","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"ebf31a4b-0d4c-498d-80a9-3fce6789eb4a","type":"LinearAxis"},{"id":"f51e3729-476a-4321-8e44-8c5ea306d5ea","type":"Grid"},{"id":"242f3e14-f95f-493b-a7ed-3dd9f4e571fc","type":"LinearAxis"},{"id":"9e45aef0-9341-4c54-92af-f8ed974fd052","type":"Grid"},{"id":"1c149d9f-043d-46ad-93d4-c134caf56aa2","type":"GlyphRenderer"}],"title":{"id":"94dc379c-96da-42ec-a53e-7de6dacb9420","type":"Title"},"tool_events":{"id":"34899e93-d ...
#             var render_items = [{"docid":"56475eb0-45ca-444e-8d3e-26ef7fdc551b","elementid":"0d4cce07-0981-4799-9

# %% [markdown]
# ### Real Data

# %%
#f = h5py.File("/Users/rishabhgupta/Downloads/2495.hdf5", "r")
f = h5py.File("./data/ecg_test.hdf5", "r")

ecg = np.array(f['/signals/ecg'])
Fs_ecg = 200
T_ecg = 1/Fs_ecg
start = 0
end = 120000
t = np.arange(np.size(ecg,0))/Fs_ecg

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
N = np.size(ecg,0)
yf = fft(ecg[:,1])
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e79d5e27-8cd2-47fe-a318-b0c217e567b3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0e886537-118d-4d1c-ae38-8232adc9ff1e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0e886537-118d-4d1c-ae38-8232adc9ff1e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0e886537-118d-4d1c-ae38-8232adc9ff1e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0e886537-118d-4d1c-ae38-8232adc9ff1e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6889f2e4-5963-49b8-863e-c1804fa3cbcc":{"roots":{"references":[{"attributes":{"callback":null},"id":"99b938ea-f75b-4819-9452-c4995d9071ce","type":"DataRange1d"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"1957735b-59a7-4dbb-ae3f-82ef587e43bb","type":"Line"},{"attributes":{},"id":"beef316e-8934-475b-87e4-9e0831c81445","type":"BasicTickFormatter"},{"attributes":{},"id":"e6f485af-16e6-4d60-808b-7bb4f62a3cac","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"
subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"83117942-87f2-4091-99b9-18b33eb67533","type":"Line"},{"attributes":{"plot":{"id":"971ce28e-36cf-4a0a- ...
#             var render_items = [{"docid":"6889f2e4-5963-49b8-863e-c1804fa3cbcc","elementid":"0e886537-118d-4d1c-a

# %% [markdown]
# ## 1.2. Filtering
#
# ### Removing unwanted information (frequencies) from the signal using filters
#
# <img src="img/filter.png" style="width: 500px;"/>

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end],ecg[start:end,1])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ### High Pass Filter

# %%
N = 2 # Filter Order
cutoff = 5
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'high') # Butterworth filter - highpass
hp_filtered_ecg = scipy.signal.filtfilt(b, a, ecg[:,1])
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Low Pass Filter

# %%
N = 2 # Filter Order
cutoff = 30
Fs_nyq = Fs_ecg/2
Wn = cutoff/Fs_nyq
b, a = scipy.signal.butter(N, Wn, 'low') # Butterworth filter - lowpass
lp_hp_filtered_ecg = scipy.signal.filtfilt(b, a, hp_filtered_ecg)
start = 0
end = 1000

# %%
fig=plt.figure(figsize=(9, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(t[start:end], lp_hp_filtered_ecg[start:end])
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# ## Fourier Transform of the filtered signal

# %%
N = np.size(lp_hp_filtered_ecg,0)
yf = fft(lp_hp_filtered_ecg)
abs_yf =  2.0/N * np.abs(yf[0:int(N/2)])
xf = np.linspace(0.0, 1.0/(2.0*T_ecg), N/2)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.

# %%
hover = HoverTool(tooltips=[
    ("(Frequency,Amplitude)", "($x, $y)"),
])
output_notebook()
p = figure(plot_width=600, plot_height=300, tools=[hover,])
p.line(x=xf, y=abs_yf, color='black')
p.xaxis.axis_label = 'Frequency (Hz)'
p.yaxis.axis_label = 'Amplitude'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7c6fb6fd-a285-49cb-82be-126357b2a552">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e329fdef-6a31-49a9-ae90-3169620b1249"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e329fdef-6a31-49a9-ae90-3169620b1249");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e329fdef-6a31-49a9-ae90-3169620b1249");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e329fdef-6a31-49a9-ae90-3169620b1249' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2a428222-d747-4c37-9b07-2de4af084aeb":{"roots":{"references":[{"attributes":{"below":[{"id":"a8b68226-d99d-4c96-8d6d-4326307120af","type":"LinearAxis"}],"left":[{"id":"783ffb60-bc7a-431f-b255-07ed86f444e6","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"a8b68226-d99d-4c96-8d6d-4326307120af","type":"LinearAxis"},{"id":"b6b6ecbf-943b-4586-9494-bc303aba0a40","type":"Grid"},{"id":"783ffb60-bc7a-431f-b255-07ed86f444e6","type":"LinearAxis"},{"id":"09a942c8-9d5d-49d0-98a7-f7728762b01f","type":"Grid"},{"id":"f4ead7e1-e061-49e2-a142-3488b896ea9e","type":"GlyphRenderer"}],"title":{"id":"3c09c159-0f69-49fb-94f1-14c421712b73","type":"Title"},"tool_events":{"id":"bb37ee43-6f72-4097-9c64-b69f8ed45784","type":"ToolEvents"},"toolbar":{"id":"a1393bbb-9419-451e-be74-3a0b123d9574","type":"Toolbar"},"x_range":{"id":"22aab5e3-8cb8-4a07-8fc2-a49ab8646c9e","type":"DataRange1d"},"y_range":{"id":"de5f2aab-6e12-45aa-82e8-51a8457c1717","type":"DataRange1d"}},"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"51a89dc7-0c8f-4e52-946e-2e7701ffcf03","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},"tooltips":[["(Frequency,Amplitude)","($x, $y)"]]},"id":"fd531751-d2d9-44b1-9970-2ae72ee1480f","type":"HoverTool"},{"attributes":{"callback":null},"id":"de5f2aab-6e12-45aa-82e8-51a8457c1717","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},"ticker":{"id":"d758bd18-363e-48df-adae-7fb0eb167f4a","type":"BasicTicker"}},"id":"09a942c8-9d5d-49d0-98a7-f7728762b01f","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fd531751-d2d9-44b1-9970-2ae72ee1480f","type":"HoverTool"}]},"id":"a1393bbb-9419-451e-be74-3a0b123d9574","type":"Toolbar"},{"attributes":{"plot":{"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},"ticker":{"id":"09ca25dc-2dc0-4505-8710-02a977f55f64","type":"BasicTicker"}},"id":"b6b6ecbf-943b-4586-9494-bc303aba0a40","type":"Grid"},{"attributes":{},"id":"09ca25dc-2dc0-4505-8710-02a977f55f64","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"3c09c159-0f69-49fb-94f1-14c421712b73","type":"Title"},{"attributes":{},"id":"bb37ee43-6f72-4097-9c64-b69f8ed45784","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc87f3ce-feb8-496d-9808-dec333f5811c","type":"Line"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"1975c859-82b0-4778-94c9-c223f30e7c48","type":"Line"},{"attributes":{"callback":null},"id":"22aab5e3-8cb8-4a07-8fc2-a49ab8646c9e","type":"DataRange1d"},{"attributes":{"axis_label":"Amplitude","formatter":{"id":"51a89dc7-0c8f-4e52-946e-2e7701ffcf03","type":"BasicTickFormatter"},"plot":{"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},"ticker":{"id":"d758bd18-363e-48df-adae-7fb0eb167f4a","type":"BasicTicker"}},"id":"783ffb60-bc7a-431f-b255-07ed86f444e6","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6035]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6035]}}},"id":"13db23ed-b6b0-4df8-a7e9-ac0cae55f8f4","type":"ColumnDataSource"},{"attributes":{},"id":"d758bd18-363e-48df-adae-7fb0eb167f4a","type":"BasicTicker"},{"attributes":{"axis_label":"Frequency (Hz)","formatter":{"id":"f3ef8492-3625-454a-bec5-2e4b53a017b3","type":"BasicTickFormatter"},"plot":{"id":"38831f2f-f1cc-4616-9495-28dc4a388df7","subtype":"Figure","type":"Plot"},"ticker":{"id":"09ca25dc-2dc0-4505-8710-02a977f55f64","type":"BasicTicker"}},"id":"a8b68226-d99d-4c96-8d6d-4326307120af","type":"LinearAxis"},{"attributes":{"data_source":{"id":"13db23ed-b6b0-4df8-a7e9-ac0cae55f8f4","type":"ColumnDataSource"},"glyph":{"id": ...
#             var render_items = [{"docid":"2a428222-d747-4c37-9b07-2de4af084aeb","elementid":"e329fdef-6a31-49a9-a

# %% [markdown]
# # 2. Feature Construction

# %%
from matplotlib import pyplot as plt
import pandas as pd
import scipy.signal 
import time
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (8,8)
df = pd.read_csv("./data/sg1.csv", header=None)
df = df.T
k = df.as_matrix(columns=None)

# %%
plt.plot(k[1][0:],'b-')
plt.show()

# %% [markdown]
# # 3. Feature Selection

# %%
df = pd.read_csv("./data/sg2.csv", header=None)
df = df.T
k2 = df.as_matrix(columns=None)

# %%
plt.subplot(1, 2, 1)
plt.plot(k[1][0:],'b-')
plt.subplot(1, 2, 2)
plt.plot(k2[1][0:],'r-')
plt.show()

# %% [markdown]
# # 4. Model Development

# %% [markdown]
# ## Regression Model
#
# ##### Fit a line through data points
#
# <img src="img/reg1.png" style="width: 500px;"/>

# %% [markdown]
# ##### Make predictions based on the fitted line
#
# <img src="img/reg2.png" style="width: 500px;"/>

# %% [markdown]
# # Example: How do we use regression in SKIIN?

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
# Regression with synthetic data
# Data
# Heart rate
hr = np.sort(np.random.randint(60, high=120, size=500))
# Stress: 0 - 1
st = np.sort(np.random.rand(500))

# %%
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.show()

# %% [markdown]
# ## Use Least Square Estimation to fit a line
#
# ##### Equation of a line: $ y = \beta_{0}  x + \beta_{1} $
#
# ##### $\beta_{0}$ and $\beta_{1}$ are the slope and intercepts of the line
#
# ##### $\beta_{0}$ and $\beta_{1}$ are also model parameters which need to be estimated
#
# ##### Least squares formula: $ \beta = (X^{-1}X)X'Y$

# %% [markdown]
# ## Least Squares Derivation
#
# <img src="img/ls_derive.png" style="width: 400px;"/>

# %%
# Estimating the coefficient and intercept using linear algebra
# Using the equation beta = inv(x'x)x'y
y = np.matrix(st)
x = np.matrix(np.column_stack(
    (hr, np.ones(len(st)))))
b = np.linalg.inv(x.T * x) * x.T * y.T

# The coefficient and intercept estimated from matrix multiplication
beta_prime_coef = b[0]
beta_prime_intrp = b[1]

y_prime = x * b

# %%
print('The equation for the line is: Stress = ' + str(b[0]) + ' * Heart Rate + ' + str(b[1]))
plt.plot(hr,st, '.')
plt.ylabel('Stress: 0 - 1')
plt.xlabel('Heart rate (bpm)')
plt.plot(hr, y_prime, '--')
plt.show()
# Out:
# The equation for the line is: Stress = [[ 0.01641475]] * Heart Rate + [[-0.98809138]]

# %% [markdown]
# ## Classification Model
#
# <img src="img/classification.png" style="width: 400px;"/>

# %% [markdown]
# ## How can we use classification model for SKIIN?

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from math import ceil, floor
from sklearn.metrics import accuracy_score
n_samples = 1000
# Mean HR
hr_1 = np.random.normal(60, 20, size=n_samples)
hr_2 = np.random.normal(100, 10, size=n_samples)

# Average minutes they worked out during the day
st_1 = np.random.normal(120, 20, n_samples)
st_2 = np.random.normal(50, 20, n_samples) + 1

# %%
# Plotting the data
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.show()

# %% [markdown]
# ## Least Squares Estimation of Model Parameters or Training

# %%
# Binary classification
# Healthy class = -1
class_1 = -1*np.ones(len(hr_1))
# Unhealthy class = 1
class_2 =  np.ones(len(hr_2))

# Training data
feat_mat1 = np.column_stack((hr_1, st_1, class_1))
feat_mat2 = np.column_stack((hr_2, st_2, class_2))

X_temp = np.vstack((feat_mat1, feat_mat2))
np.random.shuffle(X_temp)

X_train = X_temp[0:-2, 0:2]
Y_train = X_temp[0:-2, 2]

X_test = X_temp[-1, 0:2]
Y_test = X_temp[-1, 2]

X_trr = np.column_stack((X_train, np.ones(len(X_train))))
dot1 = np.linalg.inv(np.dot(X_trr.T, X_trr)) 
dot2 = np.dot(dot1,X_trr.T)
b_ls = np.dot(dot2,Y_train.T)


# Range of X-axis for the hyperplane
m_1_x = floor(np.min(X_train[:, 0]))
m_2_x = ceil(np.max(X_train[:, 0]))
x_ax = np.arange(m_1_x, m_2_x+1)

y_ls = np.zeros(len(x_ax))
for k in range(0, len(y_ls)):   
    y_ls[k] = -x_ax[k]*(b_ls[0]/b_ls[1]) - (b_ls[2]/b_ls[1])

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')
plt.show()

# %% [markdown]
# # Testing

# %%
op = np.sign(b_ls[1] * X_test[1] + b_ls[0] * X_test[0])
print('The classifier output is: ' + str(op) + ', where 1 represents unhealthy class and -1 represents healthy class. ')
print('The expected output is: ' + str(Y_test) + ', where 1 represents unhealthy class and -1 represents healthy class. ')

plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')

plt.plot(X_test[0],X_test[1],'ko')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')
plt.show()
# Out:
# The classifier output is: 1.0, where 1 represents unhealthy class and -1 represents healthy class.
# The expected output is: 1.0, where 1 represents unhealthy class and -1 represents healthy class.

# %% [markdown]
# # Perceptron approach for computing model parameters

# %%
# Initialize
w = np.zeros(len(X_train[0,0:2]))
b = 0
for k in range(0, len(X_train)):
    if np.sign(np.dot(w, X_train[k, :]) + b) != Y_train[k]:
        w = w + Y_train[k] * X_train[k, :]
        b = b + Y_train[k]

y_p = np.zeros(len(x_ax))
for k in range(0, len(y_p)):
    y_p[k] = -1*x_ax[k]*w[0]/w[1] - b/w[1]

# %%
plt.plot(hr_1,st_1, '.')
plt.plot(hr_2,st_2, '.')
plt.ylabel('Average Daily Exercise Time (mins)')
plt.xlabel('Average Daily Heart Rate (bpm)')
plt.plot(x_ax, y_ls,'g')    
plt.plot(x_ax, y_p,'r')
plt.show()

# %% [markdown]
# # Perceptron Architecture
#
#
# <img src="img/perceptron.png" style="width: 600px;"/>

# %% [markdown]
# # Biological Neuron
#
# <img src="img/biological_neuron.png" style="width: 600px;"/>

# %% [markdown]
# # Artificial Neural Network (ANN)
#
# <img src="img/ann.png" style="width: 600px;"/>

# %% [markdown]
# # Deep Neural Network (DNN)
#
# <img src="img/dnn.png" style="width: 600px;"/>

# %% [markdown]
# # DNN Examples
#
# [DeepDrive OpenAI](https://www.youtube.com/watch?v=X4u2DCOLoIg "link title")
#
#
# [NVIDIA Demo](https://www.youtube.com/watch?v=0rc4RqYLtEU "link title")
#
#
#
# [WaveNet Demo](https://deepmind.com/blog/wavenet-launches-google-assistant/ "link title")

# %% [markdown]
# # Conclusion
#
# ##### You learnt how to remove noise from the data
#
# ##### You learnt how to construct features
#
# ##### You learnt how to select features for classification/regression
#
# ##### You learnt how to develop regression and classification models

# %% [markdown]
# # Questions??
